# %% [markdown]
# # Categorical Data## Main points to remember- Category dtype is useful for repeated text labels.- It can reduce memory usage and improve grouping performance.- Categories can be ordered when the labels have a natural sequence.- Use cat methods to rename, reorder, add, or remove categories.## Quick reminderKeep the examples small and focus on the pandas API shape first, then the data-cleaning details.

# %%
import pandas as pddf = pd.DataFrame({'level': ['low', 'medium', 'high', 'medium']})df['level'] = pd.Categorical(df['level'], categories=['low', 'medium', 'high'], ordered=True)print(df['level'].cat.codes.tolist())
