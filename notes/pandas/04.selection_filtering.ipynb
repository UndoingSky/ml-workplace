# %% [markdown]
# # Selection and Filtering## Main points to remember- loc selects by labels, iloc selects by integer position.- Boolean masks are the normal way to filter rows.- Use isin, between, and query for readable conditions.- Always prefer explicit column selection when sharing notebooks.## Quick reminderKeep the examples small and focus on the pandas API shape first, then the data-cleaning details.

# %%
import pandas as pddf = pd.DataFrame({'name': ['Ana', 'Ben', 'Cara'], 'score': [91, 72, 88], 'passed': [True, False, True]})high_scores = df.loc[df['score'] >= 85, ['name', 'score']]
