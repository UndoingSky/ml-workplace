# %% [markdown]
# # Missing Values## Main points to remember- Pandas represents missing data as NaN or NA.- Use isna and notna to detect missing values.- dropna removes rows or columns with missing values.- fillna replaces missing values with a constant, statistic, or forward fill.## Quick reminderKeep the examples small and focus on the pandas API shape first, then the data-cleaning details.

# %%
import pandas as pddf = pd.DataFrame({'name': ['Ana', 'Ben', None], 'score': [91, None, 88]})print(df.isna())print(df.fillna({'name': 'Unknown', 'score': df['score'].mean()}))
