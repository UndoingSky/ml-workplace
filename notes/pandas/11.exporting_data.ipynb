# %% [markdown]
# # Exporting Data## Main points to remember- to_csv is the most common export method.- Use index=False when the row index should not be saved.- to_excel, to_json, and to_parquet are also common.- Always think about file format, encoding, and whether downstream tools need a header.## Quick reminderKeep the examples small and focus on the pandas API shape first, then the data-cleaning details.

# %%
import pandas as pddf = pd.DataFrame({'name': ['Ana', 'Ben'], 'score': [91, 87]})df.to_csv('scores.csv', index=False)df.to_json('scores.json', orient='records')
