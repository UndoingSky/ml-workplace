# %% [markdown]
# # Loading and Inspecting Data## Main points to remember- Use read_csv, read_excel, or read_json to load data.- head, tail, sample, shape, and columns give a fast overview.- info shows dtypes and missing values.- describe summarizes numeric columns quickly.## Quick reminderKeep the examples small and focus on the pandas API shape first, then the data-cleaning details.

# %%
import pandas as pddf = pd.read_csv('data.csv')print(df.head())print(df.shape)print(df.info())print(df.describe())
