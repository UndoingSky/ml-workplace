# %% [markdown]
# # Types and Dates## Main points to remember- dtypes tells you how pandas stores each column.- astype changes the storage type when the data is compatible.- to_datetime converts text into real datetime values.- DateTime columns unlock dt accessors for year, month, day, and weekday.## Quick reminderKeep the examples small and focus on the pandas API shape first, then the data-cleaning details.

# %%
import pandas as pddf = pd.DataFrame({'date': ['2026-07-01', '2026-07-15'], 'value': ['10', '20']})df['date'] = pd.to_datetime(df['date'])df['value'] = df['value'].astype(int)print(df['date'].dt.month.tolist())
