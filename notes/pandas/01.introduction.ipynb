# %% [markdown]
# # Pandas Introduction## Main points to remember- Pandas is the main tabular data library in Python.- Series is a one-dimensional labeled array.- DataFrame is a two-dimensional table with rows and columns.- Pandas works well for cleaning, filtering, grouping, and joining data.## Quick reminderKeep the examples small and focus on the pandas API shape first, then the data-cleaning details.

# %%
import pandas as pdseries = pd.Series([10, 20, 30], index=['a', 'b', 'c'])frame = pd.DataFrame({'name': ['Ana', 'Ben'], 'score': [91, 87]})print(series)print(frame)
