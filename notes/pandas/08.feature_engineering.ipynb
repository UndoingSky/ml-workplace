# %% [markdown]
# # Feature Engineering## Main points to remember- Feature engineering creates useful columns from raw data.- Use assign, map, apply, str methods, and dt accessors.- cut and qcut are common for binning numeric data.- Simple derived features often improve readability before modeling.## Quick reminderKeep the examples small and focus on the pandas API shape first, then the data-cleaning details.

# %%
import pandas as pddf = pd.DataFrame({'name': ['Ana', 'Ben'], 'birthday': ['2000-02-10', '1998-11-05'], 'score': [91, 87]})df['birthday'] = pd.to_datetime(df['birthday'])df['year'] = df['birthday'].dt.yeardf['score_band'] = pd.cut(df['score'], bins=[0, 80, 90, 100], labels=['needs work', 'good', 'excellent'])
