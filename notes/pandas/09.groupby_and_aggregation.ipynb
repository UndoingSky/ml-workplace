# %% [markdown]
# # GroupBy and Aggregation## Main points to remember- groupby splits data into groups, then aggregates each group.- Common aggregations include sum, mean, count, min, and max.- agg supports multiple statistics at once.- transform keeps the original row count while adding group-level values.## Quick reminderKeep the examples small and focus on the pandas API shape first, then the data-cleaning details.

# %%
import pandas as pddf = pd.DataFrame({'team': ['A', 'A', 'B', 'B'], 'score': [10, 15, 7, 13]})summary = df.groupby('team')['score'].agg(['mean', 'sum', 'count'])print(summary)
