# %% [markdown]
# # NumPy — Basics
#
# Introduction to creating arrays and inspecting basic properties.

# %%
import numpy as np

# 1) Create arrays
a = np.array([1, 2, 3, 4])
b = np.array([[1, 2, 3], [4, 5, 6]])

print('a:
', a)
print('b:
', b)

# %%
# 2) Array properties
print('shape:', b.shape)
print('ndim:', b.ndim)
print('size:', b.size)
print('dtype:', b.dtype)

# Multidimensional array note
print('
Multidimensional array note:')
print(f
)
