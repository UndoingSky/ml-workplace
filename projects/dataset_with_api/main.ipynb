# %% [markdown]
# https://api.themoviedb.org/3/movie/top_rated?api_key=70ad825c54a36fc72af1e86c6bcc1e16&language=en-US&page=1

# %%
import pandas as pd
import requests
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("TMDB_API_KEY")

for i in range(1, 501):
    response = requests.get(f"https://api.themoviedb.org/3/movie/top_rated?api_key={api_key}&language=en-US&page={i}")
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity']]
    df = pd.concat([df, temp_df], ignore_index=True)

df.to_csv("movies.csv", index=False)
# Out:
#        id                                       title  \
# 20000 NaN                         Accidental Partners
# 20001 NaN                                     Swapped
# 20002 NaN                    The Shawshank Redemption
# 20003 NaN                                     Michael
# 20004 NaN                               The Godfather
# ...    ..                                         ...
# 29995 NaN                                  You People
# 29996 NaN                                In the Earth
# 29997 NaN                             Banshee Chapter
# 29998 NaN                                      Serena
# 29999 NaN  Revenge of the Nerds II: Nerds in Paradise
#
#                                                 overview release_date  \
# 20000  Two women discover they were both scammed by t...   2026-03-12
# 20001  A small woodland creature and a majestic bird,...   2026-05-01
# 20002  Imprisoned in the 1940s for the double murder ...   1994-09-23
# ...
