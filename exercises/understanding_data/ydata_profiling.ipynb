# %%
import pandas as pd
from data_profiling import ProfileReport


df_titanic = pd.read_csv("train.csv")


profile = ProfileReport(df_titanic, title="Titanic Survival Data Profile", explorative=True)


profile.to_file("titanic_report.html")
