# %%
import pandas as pd
import mysql.connector

conn = mysql.connector.connect(host='localhost', user='root', password='', database='world')

df = pd.read_sql_query("SELECT * from city", conn)
df = df.iloc[:, 1:]

df.sort_values(by='Population', ascending=False)
# Out:
# C:\Users\lavig\AppData\Local\Temp\ipykernel_25004\897378058.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * from city", conn)
#                     Name CountryCode      District  Population
# 2911           Adamstown         PCN             –          42
# 2316         West Island         CCK   West Island         167
# 3332             Fakaofo         TKL       Fakaofo         300
# 3537  Città del Vaticano         VAT             –         455
# 2315              Bantam         CCK   Home Island         503
# ...                  ...         ...           ...         ...
# 938              Jakarta         IDN  Jakarta Raya     9604900
# 1889            Shanghai         CHN      Shanghai     9696300
# 205            São Paulo         BRA     São Paulo     9968485
# 2330               Seoul         KOR         Seoul     9981619
# 1023     Mumbai (Bombay)         IND   Maharashtra    10500000
#
# [4079 rows x 4 columns]
