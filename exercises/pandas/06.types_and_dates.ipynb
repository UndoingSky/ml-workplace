# %% [markdown]
# # Data types and dates
#
# Machine learning works better when columns have the right type. Numbers should be numeric, dates should be datetime, and text should stay as strings until you encode it.

# %%
import pandas as pd

markdown
# Data types and dates

Machine learning works better when columns have the right type. Numbers should be numeric, dates should be datetime, and text should stay as strings until you encode it.
code

import pandas as pd

df = pd.DataFrame({
    "age": ["19", "21", "20"],
    "joined": ["2026-01-10", "2026-03-05", "2026-04-20"],
})

# Convert text to numeric
df["age"] = df["age"].astype(int)

# Convert text to datetime
df["joined"] = pd.to_datetime(df["joined"])

print(df.dtypes)

# You can now extract useful date parts
df["join_year"] = df["joined"].dt.year
df["join_month"] = df["joined"].dt.month
print(df)
markdown
### Why this matters

- Numeric columns must be numeric before training
- Datetime columns let you extract month, day, or year features
- Wrong types can break preprocessing and model training
Python 3
python
python3
python
3.x
4
5
