# %% [markdown]
# # Grouping and aggregation
#
# Grouping lets you summarize data by category. In ML, this is useful for understanding patterns before modeling and for creating grouped statistics as features.

# %%
import pandas as pd

markdown
# Grouping and aggregation

Grouping lets you summarize data by category. In ML, this is useful for understanding patterns before modeling and for creating grouped statistics as features.
code

import pandas as pd

df = pd.DataFrame({
    "city": ["Lagos", "Delhi", "Lagos", "Delhi"],
    "score": [72, 85, 90, 75],
    "age": [19, 21, 20, 22],
})

grouped = df.groupby("city").agg({
    "score": ["mean", "max"],
    "age": ["mean"],
})

print(grouped)

# You can also create simple summaries
print(df.groupby("city")["score"].mean())
markdown
### What to remember

- `groupby()` splits the data by category
- `agg()` applies summary functions like mean, max, min, or count
- These summaries help with exploratory analysis and feature creation
Python 3
python
python3
python
3.x
4
5
